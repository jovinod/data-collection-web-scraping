# %% [markdown]
# # Web Scrapping Youtube.com
# ### Task:
# 1. Go to Youtube.com
# 2. Use selenium to type in a search term, - "Kishore kumar" or "ISB".
# 3. Scrape the top 10 links that show up in the search results. Collect data on link url, link title, subscription channel, no. of views and time when video was first uploaded or posted.
# 4. Now for each of the top 10 video links, scrape the top 50 comments (Note: you may need selenium to do the 'sort by' top comments).
# 5. For each comment, collect data on who wrote it (user handle), when it was posted, how many replies, upvotes and downvotes it received.
# 6. Build a data frame containing the results as output("output_scraping.csv")

# %% [markdown]
# # Solution

# %% [markdown]
# ### Step 1 - Import the required packages
# We need to import the required packages. This example asks to emulate searching **Kishore Kumar** songs in youtube, which will be accomplished using Selenium. Ensure that
# * Selenium is installed on your machine. You can use `pip install selenium` in Anaconda command prompt.
# * Copy the webdriver for chrome in a local folder to be used in the examples. You can download the driver from [here](https://www.seleniumhq.org/download/)
# * Since the imported data will be saved as a data frame before writing to the file, we need to import pandas as well.

# %%
# required for all the interactions with the browser
from selenium import webdriver
# required to select various elements on the page by id, name, css, xpath etc
from selenium.webdriver.common.by import By
# to be able to use the standard Keys like RETURN
from selenium.webdriver.common.keys import Keys
# required for manupalting data using data frames etc.
import pandas as pd
# in order to write records to a csv file 
import csv
# induce sleep to wait for navigation to new url
import time
from time import sleep
import numpy as np

# %% [markdown]
# ### Step 2 -  Initialize the selenium chrome driver
# We need to invoke the webdriver, which means instanciating the chrome webdriver to create a driver object
# > ! Ensure your chromewebdriver path matches the path specified below, or update the path appropriately

# %%
locationWebDriver = "D:/webdriver/chromedriver.exe"
driver = webdriver.Chrome(locationWebDriver)

# %% [markdown]
# ### Step 3 - Scrape the top 10 songs of Kishore kumar
# In this step we will perform the following actions
# * Navigate to the website youtube.com in the instantiated chrome browser.
# * Check the element for the **Search** box in the DOM.
# * How do you find out the specific element, well follow the next set of instructions
#     * Open a separate browser window manually
#     * Navigate to https://youtube.com
#     * Right click on the **Search** element on the page and choose **Inspect**. You would see the screenshot below
#     ![Find Element By ID](search.png)
#     * In this case we can use the **Id** of the element which is **"search"**
#     * Similarly find the **Id** for the search button next to the text box
# * In the **Search** box type Kishore kumar and send the **RETURN** key
# * Now in the **Results** page, select all the nodes which contain the song details. Loop through each song node and extract the attributes required using XPath
# * Create a data frame with the details of the top 10 song

# %%
try:
    # navigate to the website youtube.com
    driver.get("https://youtube.com")
    # find the element by the id search on the page
    search_box = driver.find_element_by_id("search")
    search_box.send_keys("Kishore kumar")

    # one option is to use ENTER 
    #search_box.send_keys(Keys.RETURN)

    # alternate option is to find the button element and press it 
    driver.find_element_by_id('search-icon-legacy').click()
    sleep(5)
    
    index = 1
    songList = []
    # get the DOM for the new url to identify elements
    driver.get(driver.current_url)
    time.sleep(5)
    driver.execute_script('window.scrollTo(1, 3000);')
    time.sleep(5)
    songElements = driver.find_elements_by_xpath('//div[@id="dismissable"]')
    for song in songElements:
        try:
            title = song.find_element_by_xpath('.//*[@id="video-title"]').get_attribute("title")
        except:
            title = ""
        try:
            url =  song.find_element_by_xpath('.//*[@id="video-title"]').get_attribute("href")
        except:
            url = ""
        try:
            channel = song.find_element_by_xpath('.//*[@id="byline"]').get_attribute("title")
        except:
            channel = ""
        try:
            views = song.find_element_by_xpath('.//*[@id="metadata-line"]/span[1]').text
        except:
            views = ""

        # write the data to a list. We will use this to finally write the data to a file
        songList.append((index,
                         title, 
                         url, 
                         channel, 
                         views))

        # increment the index to break at count 10
        index = index + 1
        if(index>10):
            break

    cols=['pkey','title','url','channel','views']
    songData = pd.DataFrame(songList, columns=cols)
    print('Data frame created')
    
except Exception as e:
    print(e)
    driver.close()
# Out:
# Data frame created

# %% [markdown]
# ### Step 4 - Check if the top 10 videos have been populated
# * List few records from the data frame

# %%
songData.head(10)
# Out:
#    pkey                                              title  \
# 0     1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 1     2  Top 100 Songs Of R.D Burman & Kishore Kumar | ...
# 2     3  Kishore Kumar Evergreen Hit Songs | Hindi Hit ...
# 3     4  Kishore-Amitabh Ki Evergreen Jodi | Best of Ki...
# 4     5  Chala Jata Hoon - Rajesh Khanna-Kishore Kumar-...
# 5     6                 Best of Kishore Kumar Bangla Songs
# 6     7  Kishore Kumar Junior | Trailer |  Prosenjit Ch...
# 7     8  Best Of Lata Mangeshkar & Kishore Kumar Duets ...
# 8     9  Kishore Kumar Top 10 Romantic Songs {HD} - Juk...
# 9    10                            Kishor Kumar Live On TV
#
#                                            url               channel  \
# 0  https://www.youtube.com/watch?v=b_iSFNJmAhU               Rajshri
# 1  https://www.youtube.com/watch?v=uA67M0Lihz0        Saregama Music
# 2  https://www.youtube.com/watch?v=GSmXU2Q7TU8    Bollywood Classics
# 3  https://www.youtube.com/watch?v=lKVIElw2IZM     Gaane Sune Ansune
# 4  https://www.youtube.com/watch?v=6vCbtPN9skk             Indrakr90
# 5  https://www.youtube.com/watch?v=NQhPp_FyPzE                 Up tv
# 6  https://www.youtube.com/watch?v=F5KO42OWQV0      Saregama Bengali
# 7  https://www.youtube.com/watch?v=duee3ROzuKg     Gaane Sune Ansune
# 8  https://www.youtube.com/watch?v=aqBHgUkoZCE  Shemaroo Filmi Gaane
# 9  https://www.youtube.com/watch?v=FvqvlYR_YlQ   Dattatray Mirwankar
#
#         views
# 0   17M views
# 1  3.7M views
# 2   20M views
# 3  6.4M views
# 4  995K views
# 5  2.9M views
# 6  894K views
# 7   35M views
# 8  4.1M views
# 9  3.4M views

# %% [markdown]
# ### Step 5 - Scrape top 50 comments for each song
# * In each video get the details for the comments and associated attributes like name, comment, time, upvote and downvote

# %%
try:
    commentList = []
    for index, row in songData.iterrows():
        driver.get(row["url"])
        sleep(5)
        publishedDate = driver.find_element_by_xpath('//*[@id="upload-info"]/span').text
        sleep(3)
        driver.execute_script('window.scrollTo(1, 500);')
        sleep(5)
        driver.find_element_by_id('icon-label').click()
        sleep(5)
        driver.find_element_by_xpath('//*[@id="menu"]/a[1]/paper-item/paper-item-body/div[1]').click()
        sleep(5)
        driver.execute_script('window.scrollTo(1, 20000);')
        sleep(5)
        driver.execute_script('window.scrollTo(1, 20000);')
        sleep(5)       
        commentElements = driver.find_elements_by_xpath('//ytd-comment-thread-renderer[@class="style-scope ytd-item-section-renderer"]')
        counter = 1
        for comment in commentElements:
            try:
                commentAuthor = comment.find_element_by_xpath('.//*[@id="author-text"]/span').text
            except:
                commentAuthor = ""
            try:
                commentAge = comment.find_element_by_xpath('.//*[@id="published-time-text"]/a').text
            except:
                commentAge = ""
            try:
                commentText = comment.find_element_by_xpath('.//*[@id="content-text"]').text
            except:
                commentText = ""
            try:
                commentUpvote = comment.find_element_by_xpath('.//*[@id="vote-count-middle"]').text
            except:
                commentUpvote = "0"
            try:
                commentDownvote = comment.find_element_by_xpath('.//*[@id="dislike-button"]/a').text
            except:
                commentDownvote = "0"
            try:
                commentReply = comment.find_element_by_xpath('.//*[@id="more"]/div/paper-button').text
            except:
                commentReply = "0"

            commentList.append((row["pkey"], row["title"], row["url"], row["channel"], row["views"], publishedDate, commentAuthor, commentAge, commentText, commentUpvote, commentDownvote, commentReply))
            counter = counter + 1
            if(counter > 50):
                break

    cols=['pkey', 'title', 'url', 'channel', 'views', 'publishedDate', 'commentAuthor', 'commentAge', 'commentText', 'commentUpvote', 'commentDownvote', 'commentReply']
    commentData = pd.DataFrame(commentList, columns=cols)
    print("Data frame created")
except Exception as e:
    print(e)
    driver.close()
# Out:
# Data frame created

# %%
commentData.head(500)
# Out:
#      pkey                                              title  \
# 0       1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 1       1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 2       1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 3       1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 4       1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 5       1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 6       1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 7       1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 8       1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 9       1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 10      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 11      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 12      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 13      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 14      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 15      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 16      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 17      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 18      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 19      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 20      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 21      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 22      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 23      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 24      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 25      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 26      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 27      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 28      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 29      1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# ..    ...                                                ...
# 470    10                            Kishor Kumar Live On TV
# 471    10                            Kishor Kumar Live On TV
# 472    10                            Kishor Kumar Live On TV
# 473    10                            Kishor Kumar Live On TV
# 474    10                            Kishor Kumar Live On TV
# 475    10                            Kishor Kumar Live On TV
# 476    10                            Kishor Kumar Live On TV
# 477    10                            Kishor Kumar Live On TV
# 478    10                            Kishor Kumar Live On TV
# 479    10                            Kishor Kumar Live On TV
# 480    10                            Kishor Kumar Live On TV
# 481    10                            Kishor Kumar Live On TV
# 482    10                            Kishor Kumar Live On TV
# 483    10                            Kishor Kumar Live On TV
# 484    10                            Kishor Kumar Live On TV
# 485    10                            Kishor Kumar Live On TV
# 486    10                            Kishor Kumar Live On TV
# 487    10                            Kishor Kumar Live On TV
# 488    10                            Kishor Kumar Live On TV
# 489    10                            Kishor Kumar Live On TV
# 490    10                            Kishor Kumar Live On TV
# 491    10                            Kishor Kumar Live On TV
# 492    10                            Kishor Kumar Live On TV
# 493    10                            Kishor Kumar Live On TV
# 494    10                            Kishor Kumar Live On TV
# 495    10                            Kishor Kumar Live On TV
# 496    10                            Kishor Kumar Live On TV
# 497    10                            Kishor Kumar Live On TV
# 498    10                            Kishor Kumar Live On TV
# 499    10                            Kishor Kumar Live On TV
#
#                                              url              channel  \
# 0    https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 1    https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 2    https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 3    https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 4    https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 5    https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 6    https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 7    https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 8    https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 9    https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 10   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 11   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 12   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 13   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 14   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 15   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 16   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 17   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 18   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 19   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 20   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 21   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 22   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 23   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 24   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 25   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 26   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 27   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 28   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# 29   https://www.youtube.com/watch?v=b_iSFNJmAhU              Rajshri
# ..                                           ...                  ...
# 470  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 471  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 472  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 473  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 474  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 475  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 476  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 477  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 478  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 479  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 480  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 481  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 482  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 483  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 484  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 485  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 486  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 487  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 488  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 489  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 490  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 491  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 492  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 493  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 494  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 495  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 496  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 497  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 498  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
# 499  https://www.youtube.com/watch?v=FvqvlYR_YlQ  Dattatray Mirwankar
#
#           views              publishedDate         commentAuthor  \
# 0     17M views  Published on Feb 25, 2013           Hitler Rage
# 1     17M views  Published on Feb 25, 2013          Saikat Kundu
# 2     17M views  Published on Feb 25, 2013              SK Aryan
# 3     17M views  Published on Feb 25, 2013       Jaswinder Singh
# 4     17M views  Published on Feb 25, 2013      Mazhar Ali Bhatt
# 5     17M views  Published on Feb 25, 2013       sarmila sunuwar
# 6     17M views  Published on Feb 25, 2013  Sourav Bhattacharjee
# 7     17M views  Published on Feb 25, 2013             Sudhanshu
# 8     17M views  Published on Feb 25, 2013           Ankan Dutta
# 9     17M views  Published on Feb 25, 2013          Sazani Thapa
# 10    17M views  Published on Feb 25, 2013     Arvind Shrivastav
# 11    17M views  Published on Feb 25, 2013     Barinderjit Singh
# 12    17M views  Published on Feb 25, 2013  krishnakishore lanka
# 13    17M views  Published on Feb 25, 2013            Zara Mirza
# 14    17M views  Published on Feb 25, 2013           pawan verma
# 15    17M views  Published on Feb 25, 2013          Suswata Maji
# 16    17M views  Published on Feb 25, 2013           vivek joshi
# 17    17M views  Published on Feb 25, 2013      Deanna Ramdhanie
# 18    17M views  Published on Feb 25, 2013         namita dhakal
# 19    17M views  Published on Feb 25, 2013          Nixon Bhatti
# 20    17M views  Published on Feb 25, 2013        Shishir Mondal
# 21    17M views  Published on Feb 25, 2013              MsRash84
# 22    17M views  Published on Feb 25, 2013           Vimal Kumar
# 23    17M views  Published on Feb 25, 2013          Sanjay Patel
# 24    17M views  Published on Feb 25, 2013         Kanchan Singh
# 25    17M views  Published on Feb 25, 2013          Wasi Chennai
# 26    17M views  Published on Feb 25, 2013         ashwani mehta
# 27    17M views  Published on Feb 25, 2013       Rajesh Varshney
# 28    17M views  Published on Feb 25, 2013        dinesh bangera
# 29    17M views  Published on Feb 25, 2013    ganganna talapelli
# ..          ...                        ...                   ...
# 470  3.4M views  Published on Jun 13, 2013            piu mondal
# 471  3.4M views  Published on Jun 13, 2013             1234 1234
# 472  3.4M views  Published on Jun 13, 2013         Shivam Pandey
# 473  3.4M views  Published on Jun 13, 2013            Amit Dhoke
# 474  3.4M views  Published on Jun 13, 2013           ismail omar
# 475  3.4M views  Published on Jun 13, 2013  Saleem Ahmed Qureshi
# 476  3.4M views  Published on Jun 13, 2013         KaushaL PariK
# 477  3.4M views  Published on Jun 13, 2013           yousuf khan
# 478  3.4M views  Published on Jun 13, 2013        Shafique Ahmad
# 479  3.4M views  Published on Jun 13, 2013           Saira Khan.
# 480  3.4M views  Published on Jun 13, 2013         Prashant Vyas
# 481  3.4M views  Published on Jun 13, 2013          Sayyed juned
# 482  3.4M views  Published on Jun 13, 2013        twinkle sharma
# 483  3.4M views  Published on Jun 13, 2013         Dipak Samanta
# 484  3.4M views  Published on Jun 13, 2013         Kumar Kumbhar
# 485  3.4M views  Published on Jun 13, 2013         Muhammad Khan
# 486  3.4M views  Published on Jun 13, 2013       Amit Chaturvedi
# 487  3.4M views  Published on Jun 13, 2013    P.K.Rajagopal Nair
# 488  3.4M views  Published on Jun 13, 2013      Gametarian Admin
# 489  3.4M views  Published on Jun 13, 2013         Kishor Vadher
# 490  3.4M views  Published on Jun 13, 2013        Shailesh Joshi
# 491  3.4M views  Published on Jun 13, 2013            Anil Desai
# 492  3.4M views  Published on Jun 13, 2013          Wahid Akhtar
# 493  3.4M views  Published on Jun 13, 2013         Apurva Pandya
# 494  3.4M views  Published on Jun 13, 2013      Saeed Kasim Kazi
# 495  3.4M views  Published on Jun 13, 2013          Mohan Barman
# 496  3.4M views  Published on Jun 13, 2013  surjeet pratap singh
# 497  3.4M views  Published on Jun 13, 2013          Sarfaraj Ali
# 498  3.4M views  Published on Jun 13, 2013           Rohit Pawar
# 499  3.4M views  Published on Jun 13, 2013  Eashwar Kodhandapani
#
#                 commentAge                                        commentText  \
# 0              3 years ago  SADLY!!!  KISHORE KUMAR died at the age of 58y...
# 1             5 months ago  Kishore Kumar is a genius. The people who disl...
# 2               1 year ago  Kishore da lives in our hearts... will remain ...
# 3              2 years ago  Only a dumb person with 0 knowledge of music c...
# 4              2 years ago  Kishore da!! Incredible man ( Singer+ Comedian...
# 5              2 years ago  it's very true line that old is always be gold...
# 6              2 years ago           2000 dislike ,,really???i mean really???
# 7               1 year ago  Serenity! Guys play this playlist in the mid n...
# 8              2 years ago       Happy Birthday The Legendary Kishor Kumar !!
# 9               1 year ago  These songs give me chillllss. 🔥 lit songs. Th...
# 10             2 years ago                      the best songs of the century
# 11              1 year ago  my goodness..kishore ji's voice suited rajesh ...
# 12              1 year ago          kishore da forever lives till earth lives
# 13             3 years ago  he's Great I Can bet no one will ever compete ...
# 14             2 years ago                       i love every song kishore da
# 15             2 years ago                                  thanx sooooo much
# 16    2 years ago (edited)  really old is gold what a singer, what a music...
# 17             2 years ago                                                💓💓💓
# 18             2 years ago                            Heart touching songs <3
# 19             2 years ago                             All my favourite songs
# 20             2 years ago  kishore da u r evergreen...... and will always be
# 21             2 years ago               I wonder who are these 2000 idiots??
# 22             2 years ago                Wishing a very happy birthday to Da
# 23             2 years ago                         rajesh khann  amazing hero
# 24              1 year ago  old is gold best music best singer like song 🎼...
# 25              1 year ago  Indian music is expired along with Rafi saab ,...
# 26              1 year ago                    Some news from India government
# 27           10 months ago  Kishore da is Legendry Singer of Bollywood, Ki...
# 28              1 year ago                my favourite songs... old is gold..
# 29              1 year ago                    Its very true old iss gold song
# ..                     ...                                                ...
# 470             1 year ago  591 dislike... I think  all are  suffering  fr...
# 471           3 months ago  I am seeing a lot of people including mr Mirwa...
# 472          10 months ago  No software no modern technology....phir bhi b...
# 473           6 months ago  Who are the Fools who have disliked this Marve...
# 474             1 year ago  My hair  stands! I felt oaricular emotion! Uni...
# 475           3 months ago  Kishor Da Tum Ko Dua Dainy Ko Dill Chahta hay"...
# 476  3 months ago (edited)  Kalyanji Anandji + Kishor da.. The legendary i...
# 477           3 months ago  Es video ko daily daikhta hon rooz sounta hon ...
# 478             1 year ago  Versatile singer ! Multi talented Personality ...
# 479            2 years ago  What dynamic singer and multi talented artist....
# 480           2 months ago     This man in pure love, incredible personality.
# 481             1 year ago        I love you kishore da I miss you kishore da
# 482             1 year ago  kishore da was great singer as well as great e...
# 483           2 months ago  sabke jindegika yehi safar hai,the great Kisho...
# 484           4 months ago  KISHOR KUMAR JI VARY VARY GOOD SINGER  OLD IS ...
# 485             1 year ago  Amazing voice, great singer, big fan of Kishor...
# 486           2 months ago  Pal pal Dil ke pass Kishor sir ji AAP rahte ho 😍😍
# 487           3 months ago  Late Kishore Kumar  was a singer , who had gen...
# 488            2 years ago  Bhagwan, kisi ko dusra Janam do naa do , Kisho...
# 489           2 months ago     i love u dada, none can beat you. u r the best
# 490           2 months ago             जय हो किशोरदा... आपकी आवाज सदा अमर रहे
# 491           8 months ago  Kishore Kumar !!  A complete entertainer ! The...
# 492           2 months ago                 Love you sir kishore from UK Wahid
# 493           2 months ago  kishor kumar ke anek rang is video mai milte h...
# 494            2 years ago  Kishoreji, you are alive in our memories and h...
# 495           5 months ago               kishore the best singer in the world
# 496             1 year ago  This is my life's biggest regret that I didn't...
# 497           2 months ago  Are wah kishore ji aap to kamal kardi and i lo...
# 498           2 months ago  The voice of india and I am big fan of kishor ...
# 499           5 months ago                           kishore sir  is a LEGEND
#
#     commentUpvote commentDownvote     commentReply
# 0             140                  View 23 replies
# 1              57                   View 6 replies
# 2              53                   View 9 replies
# 3              94                  View 13 replies
# 4             192                  View 12 replies
# 5             201                  View 26 replies
# 6              30                  View 11 replies
# 7              25                       View reply
# 8              18                   View 2 replies
# 9              18                       View reply
# 10            196                  View 20 replies
# 11             41                   View 3 replies
# 12             15                   View 3 replies
# 13             54                  View 14 replies
# 14             41                   View 3 replies
# 15             21                   View 5 replies
# 16             93                  View 10 replies
# 17              9                   View 2 replies
# 18             69                  View 13 replies
# 19              6                                0
# 20              6                                0
# 21              6                                0
# 22              8                                0
# 23              7                                0
# 24              6                       View reply
# 25             10                                0
# 26              6                       View reply
# 27              6                                0
# 28              6                                0
# 29              9                                0
# ..            ...             ...              ...
# 470            40                   View 3 replies
# 471            12                                0
# 472             9                                0
# 473             8                                0
# 474             9                                0
# 475             6                                0
# 476            10                                0
# 477             5                       View reply
# 478             9                       View reply
# 479            29                                0
# 480            12                       View reply
# 481            11                                0
# 482            12                                0
# 483             5                                0
# 484            14                                0
# 485            11                       View reply
# 486             9                                0
# 487             4                                0
# 488           170                  View 11 replies
# 489             9                                0
# 490             6                                0
# 491             4                                0
# 492             5                                0
# 493             6                                0
# 494            51                                0
# 495             8                                0
# 496             6                                0
# 497             7                   View 2 replies
# 498             3                                0
# 499             7                                0
#
# [500 rows x 12 columns]

# %% [markdown]
# ### Step 6 - Close the driver

# %%
driver.close()

# %% [markdown]
# ### Step 7 - Process the data before storing to file
# * Change vote count to 0 where empty
# * Convert "Published on " string from Published Date
# * Change comment reply to 0 where empty

# %%
commentData['commentReply'] = commentData.commentReply.str.replace("View all ", "")
commentData['commentReply'] = commentData.commentReply.str.replace(" replies", "")
commentData['commentReply'] = commentData.commentReply.str.replace("View reply", "1")
commentData['commentReply'] = commentData.commentReply.str.replace("View ", "")
commentData['publishedDate'] = commentData.publishedDate.str.replace("Published on ", "")
commentData['commentDownvote'] = commentData.commentDownvote.str.replace("", "0")

# %% [markdown]
# ### Step 8 - Write data to the csv file

# %%
commentData.to_csv('output_scraping.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ### Step 9
# #### Validate the file is created with relevant records
# * Read the recently created csv file and insert into a data frame
# * Read the top few records from the data frame

# %%
data = pd.read_csv('output_scraping.csv', sep=',', encoding='utf-8') 
data.head()
# Out:
#    pkey                                              title  \
# 0     1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 1     1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 2     1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 3     1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
# 4     1  Kishore Kumar Hit Songs Jukebox - Evergreen Ro...
#
#                                            url  channel      views  \
# 0  https://www.youtube.com/watch?v=b_iSFNJmAhU  Rajshri  17M views
# 1  https://www.youtube.com/watch?v=b_iSFNJmAhU  Rajshri  17M views
# 2  https://www.youtube.com/watch?v=b_iSFNJmAhU  Rajshri  17M views
# 3  https://www.youtube.com/watch?v=b_iSFNJmAhU  Rajshri  17M views
# 4  https://www.youtube.com/watch?v=b_iSFNJmAhU  Rajshri  17M views
#
#            age       commentAuthor   commentAge  \
# 0  5 years ago         Hitler Rage  3 years ago
# 1  5 years ago        Sanjay Patel  2 years ago
# 2  5 years ago  ganganna talapelli   1 year ago
# 3  5 years ago      dinesh bangera   1 year ago
# 4  5 years ago   Arvind Shrivastav  2 years ago
#
#                                          commentText commentUpvote  \
# 0  SADLY!!!  KISHORE KUMAR died at the age of 58y...           138
# 1                         rajesh khann  amazing hero             7
# 2                    Its very true old iss gold song             9
# 3                my favourite songs... old is gold..             6
# 4                      the best songs of the century           196
#
#    commentDownvote     commentReply
# 0              NaN  View 20 replies
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN  View 20 replies

# %% [markdown]
# ## Open Questions
# * Processing data
#   * Extract the date PublishedDAte
#   * Change DownVote to 0
#   * Reply Count where 1, 0
#   * Reply Count
